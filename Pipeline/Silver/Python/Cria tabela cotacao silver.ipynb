# %%
# %sql
CREATE TABLE IF NOT EXISTS cambio_radar.silver.cotacoes_ptax (
    moeda STRING,
    dataHoraCotacao TIMESTAMP,
    tipoBoletim STRING,
    sequencia_intermediario INT,
    cotacaoCompra DOUBLE,
    cotacaoVenda DOUBLE,
    paridadeCompra DOUBLE,
    paridadeVenda DOUBLE,
    run_id STRING,
    insert_dt TIMESTAMP
)
USING DELTA

# %%
# %sql 

SELECT * FROM cambio_radar.silver.cotacoes_ptax
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
